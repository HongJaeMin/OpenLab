# %% [markdown]
# **Cell 사용법**
# - 초록색 창 Code Mode : 코드를 입력 하는 상태
# - 파란색 창 Command Mode : Cell 편집하는 상태
# - Code Mode에서 ESC 키 -> Command Mode로 변환
#      - a 키 (위로 셀을 생성) b 키 (아래로 셀을 생성) x 키 (셀을 삭제)
#      - m 키 (Markdown 모드로 전환) y 키 (code 모드로 전환)

# %%
import pandas as pd # import : 라이브러리를 스크립트에서 사용할 수 있도록 호출

# %%
# 데이터 파일을 read_csv 함수로 불러온뒤, df1 변수로 선언 
df1 = pd.read_csv('Data02.csv')

# %%
df1
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1      무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 46744     카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745     카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746     카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
#        상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %% [markdown]
# # DDA (기술적 데이터 분석)
#
# - 데이터의 구조와 타입을 확인
# - 주 목표변수를 설정
# - 기술통계량 확인
#
# + 데이터 전처리

# %% [markdown]
# **데이터의 구조 파악**
#
# - 정형데이터의 구조
#     - index(row, 행, 데이터의 순서) : 데이터의 개수 확인
#     - columns (feature, 열, 항목) : 데이터의 타입 (문자/ 숫자/ 날짜)
#     - value (값) : 데이터

# %%
df1.info() # 데이터의 요약 (데이터의 구조 + 타입)
# Dtype : 문자(Object) / 숫자(int64 / float64)
# Null , 결측치(Missing Value) : 데이터가 비어있는 값 (공백) / NaN (Not A Number)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46749 entries, 0 to 46748
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제수단    46749 non-null  object
#  1   배송번호    46749 non-null  object
#  2   배송시작일   46749 non-null  object
#  3   배송완료일   46749 non-null  object
#  4   상품구매금액  46749 non-null  int64
#  5   상품번호    46661 non-null  float64
#  6   수량      46749 non-null  int64
#  7   주문경로    46749 non-null  object
#  8   주문일     46749 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# # 데이터 전처리
#
# - 데이터 추출 (행 단위/ 열 단위)
# - 데이터 정렬
# - 데이터 필터

# %%
# 행단위 추출 
df1.head() # 상위 5개의 데이터를 추출
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1  무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2  무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3  무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4  무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일
# 0   71450  1077.0   1  PC쇼핑몰  20181227
# 1  141240    42.0   2   모바일웹  20181229
# 2   13910  1271.0   1   모바일웹  20181230
# 3   81600  1085.0   1   모바일웹  20181231
# 4   94710  1106.0   1   모바일웹  20181231

# %%
df1.head(10)  # 상위 10개 데이터를 추출
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1  무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2  무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3  무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4  무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 5  무통장입금  D-20181231-0000108-01  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 6  무통장입금  D-20181231-0000184-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 7  무통장입금  D-20181231-0000184-01  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 8  무통장입금  D-20181231-0000184-02  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 9  무통장입금  D-20181231-0000184-03  2019-01-03 오전 9:30  2019-01-07 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일
# 0   71450  1077.0   1  PC쇼핑몰  20181227
# 1  141240    42.0   2   모바일웹  20181229
# 2   13910  1271.0   1   모바일웹  20181230
# ...

# %%
df1.tail() # 하위 5개의 데이터를 추출
# Out:
#       결제수단                   배송번호                배송시작일               배송완료일  \
# 46744   카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745   카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746   카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747   카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748   카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
#        상품구매금액   상품번호  수량    주문경로       주문일
# 46744   52800  445.0   1    모바일웹  20171229
# 46745  112200  172.0   2    모바일웹  20171229
# 46746   36000  140.0   1  네이버 페이  20171230
# 46747   73460  184.0   1  네이버 페이  20171231
# 46748   81620  479.0   1    모바일웹  20171231

# %%
df1.iloc[100:200] # iloc (index location) : 특정 범위의 데이터를 추출
# Out:
#       결제수단                   배송번호               배송시작일               배송완료일  \
# 100  무통장입금  D-20190102-0000213-00  2019-01-03 오전 9:28  2019-01-07 오전 5:32
# 101  무통장입금  D-20190102-0000213-01  2019-01-03 오전 9:28  2019-01-07 오전 5:32
# 102     카드  D-20190102-0000224-01  2019-01-03 오전 9:30  2019-01-08 오후 2:01
# 103  무통장입금  D-20190102-0000237-00  2019-01-03 오후 6:19  2019-01-07 오전 5:32
# 104  무통장입금  D-20190102-0000237-01  2019-01-03 오후 6:19  2019-01-07 오전 5:32
# ..     ...                    ...                 ...                 ...
# 195     카드  D-20190102-0000938-03  2019-01-03 오후 6:20  2019-01-13 오전 4:38
# 196  무통장입금  D-20190102-0000951-00  2019-01-03 오후 6:19  2019-01-07 오전 5:32
# 197     카드  D-20190102-0000964-00  2019-01-03 오후 6:19  2019-01-07 오전 5:32
# 198     카드  D-20190102-0000976-00  2019-01-03 오후 6:19  2019-01-07 오전 5:32
# 199   가상계좌  D-20190102-0000993-00  2019-01-03 오후 6:19  2019-01-07 오전 5:32
#
#      상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
df2 = df1.head(1000) # 상위 1000개 데이터를 추출하여, df2 변수로 선언

# %%
df2
# Out:
#       결제수단                   배송번호                배송시작일               배송완료일  \
# 0    무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1    무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2    무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3    무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4    무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ..     ...                    ...                  ...                 ...
# 995  무통장입금  D-20190110-0000091-00  2019-01-11 오전 10:10  2019-01-15 오전 5:32
# 996     카드  D-20190110-0000109-01  2019-01-11 오전 10:12  2019-01-19 오전 5:41
# 997  무통장입금  D-20190110-0000110-00  2019-01-11 오전 10:10  2019-01-15 오전 5:32
# 998  무통장입금  D-20190110-0000122-00  2019-01-11 오전 10:10  2019-01-15 오전 5:32
# 999  무통장입금  D-20190110-0000132-00  2019-01-11 오전 10:10  2019-01-15 오전 5:32
#
#      상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
# 설명ㅋㅋ

# %%
# 열단위 데이터 추출 (Series, 순열 : index - value, [ ])
df1['상품구매금액']
# Out:
# 0         71450
# 1        141240
# 2         13910
# 3         81600
# 4         94710
#           ...
# 46744     52800
# 46745    112200
# 46746     36000
# 46747     73460
# 46748     81620
# Name: 상품구매금액, Length: 46749, dtype: int64

# %%
df1['상품구매금액'].mean() # 평균 값 계산
# Out:
# 69368.14445228774

# %%
df1['상품구매금액'].sum() # 합 계산
# Out:
# 3242891385

# %%
# DataFrame , 데이터프레임 : index-column-value , [[ ]]
df1[['상품구매금액','수량']] # 두개 이상의 항목을 추출
# Out:
#        상품구매금액  수량
# 0       71450   1
# 1      141240   2
# 2       13910   1
# 3       81600   1
# 4       94710   1
# ...       ...  ..
# 46744   52800   1
# 46745  112200   2
# 46746   36000   1
# 46747   73460   1
# 46748   81620   1
#
# [46749 rows x 2 columns]

# %%
# 행과 열을 동시에 추출 
df1[['상품구매금액','수량','주문경로']].head(1000)
# Out:
#      상품구매금액  수량    주문경로
# 0     71450   1   PC쇼핑몰
# 1    141240   2    모바일웹
# 2     13910   1    모바일웹
# 3     81600   1    모바일웹
# 4     94710   1    모바일웹
# ..      ...  ..     ...
# 995   72270   1   PC쇼핑몰
# 996   86790   1  네이버 페이
# 997   78870   1   PC쇼핑몰
# 998  173580   2    모바일웹
# 999   94710   1    모바일웹
#
# [1000 rows x 3 columns]

# %%
df1.head(1000)['수량']
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    2
# 999    1
# Name: 수량, Length: 1000, dtype: int64

# %% [markdown]
# **데이터 정렬**

# %%
df1.sort_values(by='수량') # 오름차순 정렬 (데이터가 낮은 순서부터)
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 30310  무통장입금  D-20180824-0000184-00  2018-08-26 오후 6:32  2018-08-30 오전 5:32
# 30311  무통장입금  D-20180824-0000184-00  2018-08-26 오후 6:32  2018-08-30 오전 5:32
# 30312     카드  D-20180824-0000143-00  2018-08-26 오후 6:32  2018-08-30 오전 5:32
# 30314  무통장입금  D-20180824-0000196-01  2018-08-27 오후 7:08  2018-08-31 오전 5:32
# ...      ...                    ...                 ...                 ...
# 31697  무통장입금  D-20180907-0000185-01  2018-09-12 오후 6:31  2018-09-16 오전 5:32
# 29160  무통장입금  D-20180813-0000272-01  2018-08-13 오후 6:34  2018-08-17 오전 5:32
# 25539     카드  D-20180704-0000240-01  2018-07-05 오전 9:16  2018-07-13 오전 9:07
# 24512  무통장입금  D-20180620-0000432-00  2018-06-28 오후 6:34  2018-07-02 오전 5:32
# 38590  무통장입금  D-20181112-0000709-00  2018-11-16 오전 9:10  2018-11-20 오전 5:32
#
#         상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
df1.sort_values(by='수량', ascending=False) # 내림차순 정렬 (데이터가 높은 순서부터)
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 38590  무통장입금  D-20181112-0000709-00   2018-11-16 오전 9:10  2018-11-20 오전 5:32
# 24512  무통장입금  D-20180620-0000432-00   2018-06-28 오후 6:34  2018-07-02 오전 5:32
# 25539     카드  D-20180704-0000240-01   2018-07-05 오전 9:16  2018-07-13 오전 9:07
# 29160  무통장입금  D-20180813-0000272-01   2018-08-13 오후 6:34  2018-08-17 오전 5:32
# 31697  무통장입금  D-20180907-0000185-01   2018-09-12 오후 6:31  2018-09-16 오전 5:32
# ...      ...                    ...                  ...                 ...
# 17091  무통장입금  D-20190528-0000303-00  2019-05-29 오전 11:31  2019-06-02 오전 5:32
# 17092  무통장입금  D-20190528-0000303-01  2019-05-29 오전 11:31  2019-06-02 오전 5:32
# 17093  무통장입금  D-20190528-0000303-02  2019-05-29 오전 11:31  2019-06-02 오전 5:32
# 17094  무통장입금  D-20190528-0000303-03  2019-05-29 오전 11:31  2019-06-02 오전 5:32
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
#         상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
# '수량'이 높은 상위 100개 데이터를 추출하여, result1.xlsx 저장 
df1.sort_values(by='수량', ascending=False).head(100).to_excel('result.xlsx')

# %%
df1.sort_values(by='상품구매금액',ascending=False).head(50)
# Out:
#             결제수단                   배송번호                배송시작일  \
# 24512      무통장입금  D-20180620-0000432-00   2018-06-28 오후 6:34
# 20642      무통장입금  D-20180419-0000292-00  2018-04-21 오후 12:21
# 31697      무통장입금  D-20180907-0000185-01   2018-09-12 오후 6:31
# 29160      무통장입금  D-20180813-0000272-01   2018-08-13 오후 6:34
# 41229      무통장입금  D-20181203-0000345-00   2018-12-03 오후 6:49
# 33126      무통장입금  D-20180927-0000469-00   2018-09-28 오후 9:27
# 2615       무통장입금  D-20190125-0000167-00   2019-01-28 오전 8:49
# 8744       무통장입금  D-20190319-0000457-01   2019-03-20 오전 8:45
# 1541          카드  D-20190115-0000712-00   2019-01-17 오전 9:54
# 41162      무통장입금  D-20181203-0000084-01   2018-12-03 오후 6:49
# 11592         카드  D-20190411-0000315-02   2019-04-18 오전 9:44
# 4332       무통장입금  D-20190212-0000558-11   2019-02-14 오후 6:39
# 14878      무통장입금  D-20190508-0000724-01   2019-05-09 오후 6:32
# 39170      무통장입금  D-20181116-0000268-00   2018-11-17 오후 6:57
# ...

# %%
# 두 개 이상의 항목에 대해 정렬 
df1.sort_values(by=['수량','상품구매금액']) 
# 수량에 대해 정렬 후, 같은 수량일 때, 상품구매금액이 낮은 순서대로 정렬
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 17551  무통장입금  D-20171227-0000094-00   2018-01-02 오후 5:59  2018-01-06 오전 5:33
# 17558     카드  D-20180102-0000019-00   2018-01-02 오후 5:59  2018-01-06 오전 5:33
# 17562  무통장입금  D-20180102-0000022-00  2018-01-05 오전 10:02  2018-01-09 오전 5:35
# 17565     카드  D-20180102-0000045-00   2018-01-02 오후 5:59  2018-01-06 오전 5:33
# 17569     카드  D-20180102-0000073-00   2018-01-02 오후 5:59  2018-01-06 오전 5:33
# ...      ...                    ...                  ...                 ...
# 29160  무통장입금  D-20180813-0000272-01   2018-08-13 오후 6:34  2018-08-17 오전 5:32
# 31697  무통장입금  D-20180907-0000185-01   2018-09-12 오후 6:31  2018-09-16 오전 5:32
# 25539     카드  D-20180704-0000240-01   2018-07-05 오전 9:16  2018-07-13 오전 9:07
# 24512  무통장입금  D-20180620-0000432-00   2018-06-28 오후 6:34  2018-07-02 오전 5:32
# 38590  무통장입금  D-20181112-0000709-00   2018-11-16 오전 9:10  2018-11-20 오전 5:32
#
#         상품구매금액   상품번호  수량    주문경로       주문일
# ...

# %%
df1.sort_values(by=['수량','상품구매금액'],ascending=[True, False])
# 낮은 수량에 대해 정렬 후, 같은 수량일 때, 상품구매금액이 높은 순서대로 정렬
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 4332   무통장입금  D-20190212-0000558-11  2019-02-14 오후 6:39  2019-02-18 오전 5:32
# 11592     카드  D-20190411-0000315-02  2019-04-18 오전 9:44  2019-04-22 오전 5:32
# 23686  무통장입금  D-20180608-0000087-00  2018-06-08 오후 6:01  2018-06-12 오전 5:32
# 34259  무통장입금  D-20181009-0000381-00  2018-10-12 오후 5:52  2018-10-16 오전 5:32
# 34545  무통장입금  D-20181011-0000498-03  2018-10-12 오후 5:52  2018-10-16 오전 5:32
# ...      ...                    ...                 ...                 ...
# 31697  무통장입금  D-20180907-0000185-01  2018-09-12 오후 6:31  2018-09-16 오전 5:32
# 29160  무통장입금  D-20180813-0000272-01  2018-08-13 오후 6:34  2018-08-17 오전 5:32
# 25539     카드  D-20180704-0000240-01  2018-07-05 오전 9:16  2018-07-13 오전 9:07
# 24512  무통장입금  D-20180620-0000432-00  2018-06-28 오후 6:34  2018-07-02 오전 5:32
# 38590  무통장입금  D-20181112-0000709-00  2018-11-16 오전 9:10  2018-11-20 오전 5:32
#
#         상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %% [markdown]
# - 미션 1
#
# - 수량이 높으면서, 상품구매금액은 낮은 100명의 고객을 추출
# - result2.xlsx
# - 채팅방에 송부

# %%
df1.sort_values(by=['수량','상품구매금액'],
                ascending=[False, True]).head(100).to_excel('result2.xlsx')

# %% [markdown]
# **데이터 필터**

# %%
df1['주문경로'].unique() # 범주형 데이터의 항목 확인
# Out:
# array(['PC쇼핑몰', '모바일웹', '네이버 페이'], dtype=object)

# %%
df1['주문경로']=='네이버 페이' 
# 조건에 부합하는 값을 True / 아닌 값을 False로 출력하는 Series
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46744    False
# 46745    False
# 46746     True
# 46747     True
# 46748    False
# Name: 주문경로, Length: 46749, dtype: bool

# %%
cond1 = (df1['주문경로']=='네이버 페이')
df1.loc[cond1] # loc (location) : 특정 조건에 부합하는 데이터를 추출
# Out:
#       결제수단                   배송번호               배송시작일                배송완료일  \
# 40      카드  D-20190101-0000049-01  2019-01-03 오전 9:32   2019-01-07 오후 7:01
# 41      카드  D-20190101-0000055-01  2019-01-03 오전 9:32   2019-01-09 오후 3:47
# 47     적립금  D-20190101-0000106-01  2019-01-03 오전 9:30   2019-01-13 오전 7:19
# 57      카드  D-20190101-0000145-01  2019-01-03 오전 9:30   2019-01-07 오후 6:01
# 58     휴대폰  D-20190101-0000153-01  2019-01-03 오전 9:30  2019-01-03 오후 11:15
# ...    ...                    ...                 ...                  ...
# 46739   카드  D-20171228-0000132-03  2017-12-29 오후 4:34   2018-01-03 오전 9:20
# 46740   카드  D-20171228-0000132-04  2017-12-29 오후 4:34   2018-01-07 오전 4:55
# 46741   카드  D-20171228-0000132-05  2017-12-29 오후 4:34   2018-01-07 오전 4:55
# 46746   카드  D-20171230-0000022-01  2018-01-02 오후 7:06   2018-01-11 오전 2:46
# 46747   카드  D-20171231-0000017-01  2018-01-03 오후 2:00   2018-01-06 오후 6:06
#
#        상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
# 주문경로가 '네이버 페이'인 고객들 중, 수량이 높은 상위 100명의 명단을 추출 
cond1 = (df1['주문경로']=='네이버 페이')
df1.loc[cond1].sort_values(by='수량',ascending=False).head(100)
# Out:
#         결제수단                   배송번호                배송시작일                배송완료일  \
# 25539     카드  D-20180704-0000240-01   2018-07-05 오전 9:16   2018-07-13 오전 9:07
# 46738     카드  D-20171228-0000132-02   2017-12-29 오후 4:34  2018-01-03 오전 10:38
# 18467     카드  D-20180207-0000244-01   2018-02-07 오후 5:19   2018-02-19 오후 9:48
# 20721     카드  D-20180422-0000041-01   2018-04-23 오후 6:42   2018-04-24 오후 4:21
# 21601     카드  D-20180509-0000491-01   2018-05-10 오후 6:24  2018-05-16 오후 12:04
# ...      ...                    ...                  ...                  ...
# 22104     카드  D-20180516-0000218-01   2018-05-17 오후 1:30  2018-05-22 오전 10:10
# 8183      카드  D-20190314-0000927-04   2019-03-15 오후 6:24   2019-03-24 오전 2:49
# 8182      카드  D-20190314-0000927-03   2019-03-15 오후 6:24   2019-03-24 오전 2:49
# 22133  무통장입금  D-20180516-0000387-01  2018-05-18 오전 11:08   2018-05-22 오전 9:02
# 8228      카드  D-20190314-0001226-01   2019-03-15 오후 6:24   2019-03-24 오전 3:51
#
# ...

# %%
# 주문수량이 10개 이상인 명단을 추출하여, result3.xlsx 저장 
cond1 = (df1['수량']>=10)
df1.loc[cond1].to_excel('result3.xlsx')

# %%
# PC 쇼핑몰로 구매한 고객 중, 구매수량이 5개 이상인 고객만 추출 
cond1 = (df1['주문경로']=='PC쇼핑몰')
cond2 = (df1['수량']>=5)
df1.loc[cond1 & cond2] #  & : 두 조건을 모두 만족되는 데이터를 추출
# Out:
#             결제수단                   배송번호                배송시작일  \
# 246    적립금,무통장입금  D-20190103-0000244-00   2019-01-03 오후 6:19
# 247    적립금,무통장입금  D-20190103-0000244-01   2019-01-03 오후 6:19
# 613        무통장입금  D-20190107-0000308-00   2019-01-08 오후 6:57
# 630        무통장입금  D-20190107-0000411-00  2019-01-11 오전 10:10
# 1308       무통장입금  D-20190114-0000174-04   2019-01-16 오전 9:01
# ...          ...                    ...                  ...
# 45885   쿠폰,무통장입금  D-20170904-0000042-01   2017-09-04 오후 4:49
# 45954     적립금,카드  D-20170920-0000021-01   2017-09-20 오후 5:38
# 46107         카드  D-20171020-0000024-00   2017-10-20 오후 3:49
# 46270         카드  D-20171113-0000056-00   2017-11-13 오후 1:45
# 46647         카드  D-20171219-0000055-00   2017-12-19 오후 4:36
#
#                     배송완료일  상품구매금액    상품번호  수량   주문경로       주문일
# 246    2019-01-07 오전 5:32  601920  1374.0   8  PC쇼핑몰  20190103
# 247    2019-01-07 오전 5:32  444290  1373.0   7  PC쇼핑몰  20190103
# ...

# %%
cond1 = (df1['주문경로']=='PC쇼핑몰')
cond2 = (df1['주문경로']=='네이버 페이')
df1.loc[cond1 | cond2] # | : 두 조건 중 하나이상 만족되는 데이터를 추출
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 6      무통장입금  D-20181231-0000184-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 7      무통장입금  D-20181231-0000184-01  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 8      무통장입금  D-20181231-0000184-02  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 9      무통장입금  D-20181231-0000184-03  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# ...      ...                    ...                 ...                 ...
# 46739     카드  D-20171228-0000132-03  2017-12-29 오후 4:34  2018-01-03 오전 9:20
# 46740     카드  D-20171228-0000132-04  2017-12-29 오후 4:34  2018-01-07 오전 4:55
# 46741     카드  D-20171228-0000132-05  2017-12-29 오후 4:34  2018-01-07 오전 4:55
# 46746     카드  D-20171230-0000022-01  2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01  2018-01-03 오후 2:00  2018-01-06 오후 6:06
#
#        상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %% [markdown]
# - 미션2
#
# - '주문경로'가 '모바일 웹' 주문한 사람들 중
# - '상품구매금액'이 100,000원 이상인 고객들을 추출하여,
# - '수량'이 높은 상위 30명의 고객 명단을 추출
# - result_member.xlsx
# - 채팅창에 송부 (45분까지)

# %%
df1['주문경로'].unique()
# Out:
# array(['PC쇼핑몰', '모바일웹', '네이버 페이'], dtype=object)

# %%
모바일웹
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-86c1ab22291d> in <module>
# ----> 1 모바일웹
#
# NameError: name '모바일웹' is not defined

# %%
cond1 = (df1['주문경로']=='모바일웹')
cond2 = (df1['상품구매금액']>=100000)

df1.loc[cond1&cond2].sort_values(by='수량', 
                       ascending=False).head(30).to_excel('result_member.xlsx')

# %%
297.375**(1/2)

# %% [markdown]
# # 기술 통계량 확인

# %% [markdown]
# **범주형 데이터 통계량 확인**

# %%
# 범주형 데이터의 항목을 확인 
df1['결제수단'].unique()

# %%
# 범주형 데이터의 빈도수를 확인 
df1['결제수단'].value_counts()

# %%
df1['주문경로'].value_counts()

# %%
df1.describe(include='object')
# 모든 범주형 데이터의 항목 확인
# count: 데이터 수 / unique: 항목 수 / top: 가장 많은 항목 / freq: 가장많은 항목의 수

# %% [markdown]
# **연속형 숫자데이터 기술통계량**

# %%
df1['상품구매금액'].mean() # 평균

# %%
df1['상품구매금액'].median() # 중앙값

# %%
df1['상품구매금액'].max() # 최대값

# %%
df1['상품구매금액'].min() # 최소값

# %%
df1['상품구매금액'].var() # 분산

# %%
df1['상품구매금액'].std() # 표준편차

# %%
# 모든 연속형 숫자데이터의 기술통계량 확인 
df1.describe()
# count : 데이터 수 / mean : 평균 / std : 표준편차
# min , max : 최소 최대값 / 50% :  중앙값

# %%
# 숫자데이터 + 문자데이터 기술통계량을 같이 확인
df1.describe(include=['object','int64','float64'])

# %%
df1.describe(include=['object','int64','float64']).to_excel('result3.xlsx')

# %% [markdown]
# # 데이터 전처리 2
#
# - 데이터 요약
# - 데이터 병합

# %%
df1['주문경로'].value_counts()

# %%
df1['상품구매금액'].mean()

# %% [markdown]
# - 채널 분석 (주문 경로에 따라 매출액의 차이가 있을까?)

# %%
# '주문 경로'에 대한 '상품 구매금액'의 평균을 계산 
df1.pivot_table(index='주문경로', values='상품구매금액')

# %%
df1.pivot_table(index='주문경로',values='상품구매금액',aggfunc='median')

# %%
df1.pivot_table(index='주문경로',values='상품구매금액',
                aggfunc=['mean','median','max'])
# 데이터 개수가 많으면 많을 수록, 이상치에 의한 변동효과가 줄어든다

# %%
df1.pivot_table(index='주문경로',values='상품구매금액',
                aggfunc=['mean','median','max']).to_excel('result4.xlsx')

# %%
df1.pivot_table(index='주문경로',values=['상품구매금액','수량'],
               aggfunc='sum')

# %%
df1.pivot_table(index=['주문경로','결제수단'],values='수량',aggfunc='sum')

# %%
df1.pivot_table(index='주문경로',values='수량',aggfunc='sum',columns='결제수단')

# %% [markdown]
# - 미션 4
#
# - 결제수단에서 '무통장입금' 데이터만 추출
# - 주문 경로 별, 상품 구매금액의 합/평균/중앙값을 계산한 데이터 테이블 생성
# - result5.xlsx
# - 채팅창에 업로드 (23분 까지)

# %%
cond1 = (df1['결제수단']=='무통장입금')
df1.loc[cond1].pivot_table(index='주문경로',values='상품구매금액',
                          aggfunc=['sum','mean','median']).to_excel('result5.xlsx')

# %% [markdown]
# - 숙제
#
# 1.  연체건수가 가장 높은 고객 50명 추출
#     -> result_ex1.xlsx
# 2.  결제은행'현대카드'를 이용해서 결제한 고객 중, '월랜탈비용'이 높은 상위 100명 추출
#     -> result_ex2.xlsx
# 3.  판매유형이 '렌탈'이면서, 계약기간이 30개월 이상인 고객들을 추출 한 뒤,
#     연체건수가 낮은 순서대로 정렬
#     -> result_ex3.xlsx
# 4.  제품군에서 DES-1 제품을 사용하는 고객들을 추출,
#     결제 은행 별, 월랜탈비용의 합을 계산한 테이블(pivot)
#     -> result_ex4.xlsx
# 5.  Data03.csv 데이터의 연속형데이터의 요약 통계량을 계산해서 (describe)
#     -> result_ex5.xlsx
# 6.  분석 스크립트 까지 송부
#     -> ex1.ipynb
#
# - 0001jmp@gmail.com (기한 : 11월 12일->13일 00시00분 까지)

# %%
pd.read_csv('Data03.csv')

# %% [markdown]
# - 판매량 분석 (일자 별 총 판매량)
# - 채널 분석 (주문 경로 분석)
# - 배송기간 분석
